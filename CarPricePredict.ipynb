# %%
import numpy as np
import pandas as pd

# %%
cars = pd.read_csv(r"C:\Users\Administrator\Downloads\sbnt\train (1).csv")

# %%
cars
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
cars.shape
# Out:
# (6019, 13)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               6019 non-null   object
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int64
#  3   Kilometers_Driven  6019 non-null   int64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6017 non-null   object
#  8   Engine             5983 non-null   object
#  9   Power              5983 non-null   object
#  10  Seats              5977 non-null   float64
#  11  New_Price          824 non-null    object
#  12  Price              6019 non-null   float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 611.4+ KB

# %% [markdown]
# ### Performing Data Cleaning
#
# - year column has invalid data
# - year data type is object, have to change in int
# - price column has value 'Ask For Price'.
# - price column is object
# - In price column, we have to remove ','.
# - kms column has value: 'nan', 'price'
# - in kms column, we have to remove 'kms' unit and ','.
# - column kms is object.
# - Fuel_type column has 'nan' values
# - Keep first 3 words of name columns

# %%
cars['Year'].unique()
# Out:
# array([2010, 2015, 2011, 2012, 2013, 2016, 2018, 2014, 2017, 2007, 2009,
#        2008, 2019, 2006, 2005, 2004, 2002, 2000, 2003, 1999, 2001, 1998],
#       dtype=int64)

# %%
cars['Price'].unique()
# Out:
# array([ 1.75, 12.5 ,  4.5 , ...,  2.27, 17.56,  7.43])

# %%
cars['Kilometers_Driven'].unique()
# Out:
# array([72000, 41000, 46000, ..., 45004, 70602, 27365], dtype=int64)

# %%
cars['Fuel_Type'].unique()
# Out:
# array(['CNG', 'Diesel', 'Petrol', 'LPG', 'Electric'], dtype=object)

# %%
#Doing data cleaning

# %%
#Creating backup copy
backup = cars.copy()

# %%
cars.head(3)
# Out:
#                                Name Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG   Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option     Pune  2015              41000
# 2                      Honda Jazz V  Chennai  2011              46000
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# 2  8.61 Lakh   4.50

# %%
#Cleaning year column.
cars = cars[cars['year'].str.isnumeric()]

# %%
cars['Year'].unique()
# Out:
# array([2010, 2015, 2011, 2012, 2013, 2016, 2018, 2014, 2017, 2007, 2009,
#        2008, 2019, 2006, 2005, 2004, 2002, 2000, 2003, 1999, 2001, 1998],
#       dtype=int64)

# %%
cars['Year']= cars['Year'].astype('int32')

# %%
#Cleaning Price column

# %%
cars = cars[cars['Price'] != 'Ask For Price']

# %%
#cars['Price']= cars['Price'].str.replace(',','')

# %%
cars['Price'] = cars['Price'].astype('int')

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               6019 non-null   object
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int32
#  3   Kilometers_Driven  6019 non-null   int64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6017 non-null   object
#  8   Engine             5983 non-null   object
#  9   Power              5983 non-null   object
#  10  Seats              5977 non-null   float64
#  11  New_Price          824 non-null    object
#  12  Price              6019 non-null   int32
# dtypes: float64(1), int32(2), int64(1), object(9)
# memory usage: 564.4+ KB

# %%
cars.isna().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
cars.drop("New_Price" ,axis=1 ,inplace =True)

# %%
cars.Name
# Out:
# 0                 Maruti Wagon R LXI CNG
# 1       Hyundai Creta 1.6 CRDi SX Option
# 2                           Honda Jazz V
# 3                      Maruti Ertiga VDI
# 4        Audi A4 New 2.0 TDI Multitronic
#                       ...
# 6014                    Maruti Swift VDI
# 6015            Hyundai Xcent 1.1 CRDi S
# 6016               Mahindra Xylo D4 BSIV
# 6017                  Maruti Wagon R VXI
# 6018               Chevrolet Beat Diesel
# Name: Name, Length: 6019, dtype: object

# %%
cars.Name = cars.Name.apply(lambda x :" ".join(x.split()[0:2]))

# %%
cars.Name.nunique()
# Out:
# 216

# %%
cars.sample()
# Out:
#                Name    Location  Year  Kilometers_Driven Fuel_Type  \
# 2840  Hyundai Verna  Coimbatore  2013              66930    Petrol
#
#      Transmission Owner_Type    Mileage   Engine      Power  Seats  Price
# 2840       Manual      First  17.1 kmpl  1591 CC  121.3 bhp    5.0      6

# %%
cars.Mileage.value_counts()
# Out:
# Mileage
# 18.9 kmpl     172
# 17.0 kmpl     172
# 18.6 kmpl     119
# 20.36 kmpl     88
# 21.1 kmpl      86
#              ...
# 27.28 kmpl      1
# 14.57 kmpl      1
# 22.8 km/kg      1
# 8.0 kmpl        1
# 17.24 kmpl      1
# Name: count, Length: 442, dtype: int64

# %%
cars.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'Price'],
#       dtype='object')

# %%
cars.Mileage.isna().sum()
# Out:
# 2

# %%
cars.drop(cars[cars.Mileage.isna()].index, inplace =True)

# %%
index= cars[cars.Power.isna()].index  # include only the rows where the 'Power' column has missing values.
cars[cars.Power.isna()] # inspecting the actual rows that have missing values in the 'Power' column.
# Out:
#                 Name    Location  Year  Kilometers_Driven Fuel_Type  \
# 194       Honda City   Ahmedabad  2007              60006    Petrol
# 208     Maruti Swift     Kolkata  2010              42001    Petrol
# 733     Maruti Swift     Chennai  2006              97800    Petrol
# 749       Land Rover      Mumbai  2008              55001    Diesel
# 1294      Honda City       Delhi  2009              55005    Petrol
# 1327    Maruti Swift   Hyderabad  2015              50295    Petrol
# 1385      Honda City        Pune  2004             115000    Petrol
# 1460      Land Rover  Coimbatore  2008              69078    Petrol
# 2074    Maruti Swift        Pune  2011              24255    Petrol
# 2096  Hyundai Santro  Coimbatore  2004              52146    Petrol
# 2264    Toyota Etios        Pune  2012              24500    Petrol
# 2325    Maruti Swift        Pune  2015              67000    Petrol
# 2335    Maruti Swift      Mumbai  2007              55000    Petrol
# ...

# %%
cars.drop(index ,inplace =True)

# %%
cars.isna().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                6
# Price                0
# dtype: int64

# %%
cars.Mileage =cars.Mileage.apply(lambda x :  x.split()[0])
cars.Mileage
# Out:
# 0        26.6
# 1       19.67
# 2        18.2
# 3       20.77
# 4        15.2
#         ...
# 6014     28.4
# 6015     24.4
# 6016     14.0
# 6017     18.9
# 6018    25.44
# Name: Mileage, Length: 5981, dtype: object

# %%
cars.head()
# Out:
#             Name    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0   Maruti Wagon      Mumbai  2010              72000       CNG       Manual
# 1  Hyundai Creta        Pune  2015              41000    Diesel       Manual
# 2     Honda Jazz     Chennai  2011              46000    Petrol       Manual
# 3  Maruti Ertiga     Chennai  2012              87000    Diesel       Manual
# 4        Audi A4  Coimbatore  2013              40670    Diesel    Automatic
#
#   Owner_Type Mileage   Engine      Power  Seats  Price
# 0      First    26.6   998 CC  58.16 bhp    5.0      1
# 1      First   19.67  1582 CC  126.2 bhp    5.0     12
# 2      First    18.2  1199 CC   88.7 bhp    5.0      4
# 3      First   20.77  1248 CC  88.76 bhp    7.0      6
# 4     Second    15.2  1968 CC  140.8 bhp    5.0     17

# %%
cars.Power.str.contains("n").sum()
# Out:
# 107

# %%
index =cars[cars.Power.str.contains("n")].index
cars.drop(index ,inplace=True)

# %%
cars.Engine.str.contains("N").sum()
# Out:
# 0

# %%
cars.Engine =cars.Engine.apply(lambda x : x.split()[0])
cars.Power =cars.Power.apply(lambda x : x.split()[0])

# %%
cars.dropna(subset=["Seats"] , inplace =True)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5872 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               5872 non-null   object
#  1   Location           5872 non-null   object
#  2   Year               5872 non-null   int32
#  3   Kilometers_Driven  5872 non-null   int64
#  4   Fuel_Type          5872 non-null   object
#  5   Transmission       5872 non-null   object
#  6   Owner_Type         5872 non-null   object
#  7   Mileage            5872 non-null   object
#  8   Engine             5872 non-null   object
#  9   Power              5872 non-null   object
#  10  Seats              5872 non-null   float64
#  11  Price              5872 non-null   int32
# dtypes: float64(1), int32(2), int64(1), object(8)
# memory usage: 550.5+ KB

# %%
cars.reindex(index= np.arange(0,5872))
# Out:
#                 Name    Location    Year  Kilometers_Driven Fuel_Type  \
# 0       Maruti Wagon      Mumbai  2010.0            72000.0       CNG
# 1      Hyundai Creta        Pune  2015.0            41000.0    Diesel
# 2         Honda Jazz     Chennai  2011.0            46000.0    Petrol
# 3      Maruti Ertiga     Chennai  2012.0            87000.0    Diesel
# 4            Audi A4  Coimbatore  2013.0            40670.0    Diesel
# ...              ...         ...     ...                ...       ...
# 5867    Skoda Superb      Mumbai  2017.0            35000.0    Diesel
# 5868           BMW 3       Kochi  2014.0            51240.0    Diesel
# 5869    Maruti Wagon     Kolkata  2011.0            37000.0    Petrol
# 5870    Renault KWID       Kochi  2017.0            32587.0    Petrol
# 5871  Ford Endeavour        Pune  2009.0           180000.0    Diesel
#
#      Transmission Owner_Type Mileage Engine  Power  Seats  Price
# ...

# %%
cars = cars[cars['Kilometers_Driven'] != 'Petrol']

# %%
cars['Kilometers_Driven'] = cars['Kilometers_Driven'].astype('int')

# %%
#Cleaning fuel_type
cars = cars[~cars['Fuel_Type'].isna()]

# %%
#cleaning name column
cars['Name'] = cars['Name'].str.split(' ').str.slice(0,3).str.join(' ')

# %%
cars.head()
# Out:
#             Name    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0   Maruti Wagon      Mumbai  2010              72000       CNG       Manual
# 1  Hyundai Creta        Pune  2015              41000    Diesel       Manual
# 2     Honda Jazz     Chennai  2011              46000    Petrol       Manual
# 3  Maruti Ertiga     Chennai  2012              87000    Diesel       Manual
# 4        Audi A4  Coimbatore  2013              40670    Diesel    Automatic
#
#   Owner_Type Mileage Engine  Power  Seats  Price
# 0      First    26.6    998  58.16    5.0      1
# 1      First   19.67   1582  126.2    5.0     12
# 2      First    18.2   1199   88.7    5.0      4
# 3      First   20.77   1248  88.76    7.0      6
# 4     Second    15.2   1968  140.8    5.0     17

# %%
cars.reset_index(drop=True)
# Out:
#                 Name    Location  Year  Kilometers_Driven Fuel_Type  \
# 0       Maruti Wagon      Mumbai  2010              72000       CNG
# 1      Hyundai Creta        Pune  2015              41000    Diesel
# 2         Honda Jazz     Chennai  2011              46000    Petrol
# 3      Maruti Ertiga     Chennai  2012              87000    Diesel
# 4            Audi A4  Coimbatore  2013              40670    Diesel
# ...              ...         ...   ...                ...       ...
# 5867    Maruti Swift       Delhi  2014              27365    Diesel
# 5868   Hyundai Xcent      Jaipur  2015             100000    Diesel
# 5869   Mahindra Xylo      Jaipur  2012              55000    Diesel
# 5870    Maruti Wagon     Kolkata  2013              46000    Petrol
# 5871  Chevrolet Beat   Hyderabad  2011              47000    Diesel
#
#      Transmission Owner_Type Mileage Engine  Power  Seats  Price
# 0          Manual      First    26.6    998  58.16    5.0      1
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5872 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               5872 non-null   object
#  1   Location           5872 non-null   object
#  2   Year               5872 non-null   int32
#  3   Kilometers_Driven  5872 non-null   int32
#  4   Fuel_Type          5872 non-null   object
#  5   Transmission       5872 non-null   object
#  6   Owner_Type         5872 non-null   object
#  7   Mileage            5872 non-null   object
#  8   Engine             5872 non-null   object
#  9   Power              5872 non-null   object
#  10  Seats              5872 non-null   float64
#  11  Price              5872 non-null   int32
# dtypes: float64(1), int32(3), object(8)
# memory usage: 656.6+ KB

# %%
cars.describe()
# Out:
#               Year  Kilometers_Driven        Seats        Price
# count  5872.000000       5.872000e+03  5872.000000  5872.000000
# mean   2013.477691       5.831700e+04     5.283719     9.131131
# std       3.164568       9.216941e+04     0.805081    11.290568
# min    1998.000000       1.710000e+02     2.000000     0.000000
# 25%    2012.000000       3.342250e+04     5.000000     3.000000
# 50%    2014.000000       5.260900e+04     5.000000     5.000000
# 75%    2016.000000       7.240275e+04     5.000000    10.000000
# max    2019.000000       6.500000e+06    10.000000   160.000000

# %% [markdown]
# - We can see that 25% - 75% are under 5 lakhs unders Price column. But in the max value is directly 85 lakhs. Means it clearly an outliear. We have to remove that
# - There is one car that has price 85 lakh.

# %%
cars = cars[cars['Price'] < 6e6].reset_index(drop=True)

# %%
cars
# Out:
#                 Name    Location  Year  Kilometers_Driven Fuel_Type  \
# 0       Maruti Wagon      Mumbai  2010              72000       CNG
# 1      Hyundai Creta        Pune  2015              41000    Diesel
# 2         Honda Jazz     Chennai  2011              46000    Petrol
# 3      Maruti Ertiga     Chennai  2012              87000    Diesel
# 4            Audi A4  Coimbatore  2013              40670    Diesel
# ...              ...         ...   ...                ...       ...
# 5867    Maruti Swift       Delhi  2014              27365    Diesel
# 5868   Hyundai Xcent      Jaipur  2015             100000    Diesel
# 5869   Mahindra Xylo      Jaipur  2012              55000    Diesel
# 5870    Maruti Wagon     Kolkata  2013              46000    Petrol
# 5871  Chevrolet Beat   Hyderabad  2011              47000    Diesel
#
#      Transmission Owner_Type Mileage Engine  Power  Seats  Price
# 0          Manual      First    26.6    998  58.16    5.0      1
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(cars)

# %%
colums = ["Mileage","Engine","Power"]
for col in colums :
    plt.title(f"Price to {col}")
    sns.scatterplot(data = cars , x=col ,y="Price")
    plt.xlabel(col)
    plt.ylabel("Price")
    plt.show()

# %%
colums = ["Mileage","Engine","Power"]
for col in colums :
    plt.title(f"Price to {col}")
    sns.scatterplot(data = cars , x=col ,y="Price")
    plt.xlabel(col)
    plt.ylabel("Price")
    plt.show()

# %%
cars.iloc[cars.Price.argmax()]["Name"]
# Out:
# 'Land Rover'

# %%
cars["Type"] = cars.Name.apply(lambda x :x.split()[0])

# %%
plt.figure(figsize=(10,10))
plt.title("Distribution of Brands")

sns.countplot(y=cars.Type,palette = 'coolwarm')
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_17396\2165467040.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=cars.Type,palette = 'coolwarm')

# %%
pd.DataFrame(cars.Type.value_counts()[:5])
# Out:
#                count
# Type
# Maruti          1175
# Hyundai         1058
# Honda            600
# Toyota           394
# Mercedes-Benz    316

# %%
plt.figure(figsize=(20,6))
plt.title("Distribution of price of Brands")
figure = sns.barplot(data= cars , x ="Type" ,y="Price",palette='coolwarm')
for contain in figure.containers :
    figure.bar_label(contain)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_17396\1354723254.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   figure = sns.barplot(data= cars , x ="Type" ,y="Price",palette='coolwarm')

# %%
pd.DataFrame(np.round(cars.groupby("Type")["Price"].mean(),2).sort_values(ascending=False))
# Out:
#                 Price
# Type
# Lamborghini    120.00
# Bentley         59.00
# Porsche         48.88
# Land            39.46
# Jaguar          37.30
# Mini            26.54
# Mercedes-Benz   26.54
# Audi            25.16
# BMW             25.02
# Isuzu           20.00
# Volvo           18.52
# Jeep            18.33
# ISUZU           12.00
# Toyota          11.44
# Mitsubishi      10.63
# Force            9.33
# Mahindra         7.62
# Skoda            7.10
# Ford             6.49
# Renault          5.33
# Hyundai          5.01
# Honda            4.93
# Volkswagen       4.79
# Nissan           4.31
# Maruti           4.06
# Tata             3.11
# Fiat             3.04
# Chevrolet        2.56
# Datsun           2.54
# Ambassador       1.00

# %%
sns.countplot(data =cars , x= "Fuel_Type",palette='coolwarm')
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_17396\3680601098.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data =cars , x= "Fuel_Type",palette='coolwarm')

# %%
pd.DataFrame(cars.Fuel_Type.value_counts())
# Out:
#            count
# Fuel_Type
# Diesel      3152
# Petrol      2655
# CNG           55
# LPG           10

# %%
cars.sample()
# Out:
#                    Name   Location  Year  Kilometers_Driven Fuel_Type  \
# 2685  Mercedes-Benz New  Bangalore  2012              49000    Diesel
#
#      Transmission Owner_Type Mileage Engine   Power  Seats  Price  \
# 2685    Automatic     Second   14.84   2143  167.62    5.0     19
#
#                Type
# 2685  Mercedes-Benz

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data= cars ,x= "Price",y="Location", palette='coolwarm')
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_17396\887792839.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data= cars ,x= "Price",y="Location", palette='coolwarm')

# %%
pd.DataFrame(np.round(cars.groupby("Location")["Price"].mean(),2).sort_values(ascending=False))
# Out:
#             Price
# Location
# Coimbatore  14.62
# Bangalore   13.20
# Kochi       10.74
# Hyderabad    9.45
# Delhi        9.31
# Mumbai       8.93
# Ahmedabad    8.04
# Chennai      7.51
# Pune         6.50
# Jaipur       5.48
# Kolkata      5.24

# %%
pd.crosstab( index=cars["Type" ],columns=  cars["Location"],values=cars.Price
            ,aggfunc=["mean"]).fillna(0)
# Out:
#                     mean                                               \
# Location       Ahmedabad  Bangalore    Chennai Coimbatore       Delhi
# Type
# Ambassador      0.000000   0.000000   1.000000   0.000000    0.000000
# Audi           14.300000  28.093750  26.444444  31.980000   18.629630
# BMW            24.133333  29.500000  27.962963  30.242424   20.437500
# Bentley         0.000000   0.000000   0.000000   0.000000    0.000000
# Chevrolet       3.000000   3.428571   1.923077   4.000000    1.333333
# Datsun          0.000000   2.500000   2.000000   3.000000    0.000000
# Fiat            0.000000   0.000000   2.000000   5.000000    1.000000
# Force           0.000000   0.000000  12.000000   0.000000    0.000000
# Ford            5.000000   4.250000   5.444444  10.375000    7.823529
# Honda           5.192308   5.230769   4.371429   6.560976    3.846154
# Hyundai         5.282609   5.961538   4.352113   7.383459    4.561798
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from scipy.stats import pearsonr

kilometers = data['Kilometers_Driven']
price = data['Price']

kilometers_reshaped = kilometers.values.reshape(-1, 1)

#
scaler = StandardScaler()

kilometers_scaled = scaler.fit_transform(kilometers_reshaped)

corr_coef, p_value = pearsonr(kilometers_scaled.flatten(), price)

# Output the results
print("Pearson correlation coefficient after scaling:", corr_coef)
print("P-value after scaling:", p_value)

# %%
cars.iloc[cars.Year.argmin()]["Name"]
# Out:
# 'Maruti Zen'

# %%
#Saving the new Data
cars.to_csv('Datacleaned_cars.csv')

# %% [markdown]
# ### Creating Model

# %%
#Splitting input and output columns
X = cars.drop(columns='Price')
y = cars['Price']

# %%
X #input
# Out:
#                 Name    Location  Year  Kilometers_Driven Fuel_Type  \
# 0       Maruti Wagon      Mumbai  2010              72000       CNG
# 1      Hyundai Creta        Pune  2015              41000    Diesel
# 2         Honda Jazz     Chennai  2011              46000    Petrol
# 3      Maruti Ertiga     Chennai  2012              87000    Diesel
# 4            Audi A4  Coimbatore  2013              40670    Diesel
# ...              ...         ...   ...                ...       ...
# 5867    Maruti Swift       Delhi  2014              27365    Diesel
# 5868   Hyundai Xcent      Jaipur  2015             100000    Diesel
# 5869   Mahindra Xylo      Jaipur  2012              55000    Diesel
# 5870    Maruti Wagon     Kolkata  2013              46000    Petrol
# 5871  Chevrolet Beat   Hyderabad  2011              47000    Diesel
#
#      Transmission Owner_Type Mileage Engine  Power  Seats       Type
# 0          Manual      First    26.6    998  58.16    5.0     Maruti
# ...

# %%
y #ouput
# Out:
# 0        1
# 1       12
# 2        4
# 3        6
# 4       17
#         ..
# 5867     4
# 5868     4
# 5869     2
# 5870     2
# 5871     2
# Name: Price, Length: 5872, dtype: int32

# %% [markdown]
# #### Performing Train-Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
#Since it a prediction project on numerical data(price), we have to use Regression. 
#So, we using Linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder

# %%
Name	Location	Year	Kilometers_Driven	Fuel_Type	Transmission	Owner_Type	Mileage	Engine	Power	Seats
0	Maruti Wagon	Mumbai	2010

# %%
cars.head(5)
# Out:
#             Name    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0   Maruti Wagon      Mumbai  2010              72000       CNG       Manual
# 1  Hyundai Creta        Pune  2015              41000    Diesel       Manual
# 2     Honda Jazz     Chennai  2011              46000    Petrol       Manual
# 3  Maruti Ertiga     Chennai  2012              87000    Diesel       Manual
# 4        Audi A4  Coimbatore  2013              40670    Diesel    Automatic
#
#   Owner_Type Mileage Engine  Power  Seats  Price     Type
# 0      First    26.6    998  58.16    5.0      1   Maruti
# 1      First   19.67   1582  126.2    5.0     12  Hyundai
# 2      First    18.2   1199   88.7    5.0      4    Honda
# 3      First   20.77   1248  88.76    7.0      6   Maruti
# 4     Second    15.2   1968  140.8    5.0     17     Audi

# %%
ohe = OneHotEncoder()
ohe.fit(X_train[['Name','Location','Fuel_Type','Transmission','Owner_Type','Type']])
# Out:
# OneHotEncoder()

# %% [markdown]
# ### Creating a column transformer to transform categorical columns

# %%
from sklearn.compose import make_column_transformer

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_,handle_unknown="ignore"),['Name','Location','Fuel_Type','Transmission','Owner_Type','Type']),
                                    remainder='passthrough')

# %% [markdown]
# ### Linear Regression Model

# %%
lr = LinearRegression()

# %% [markdown]
# ### Making a pipeline

# %%
from sklearn.pipeline import make_pipeline

# %%
pipe = make_pipeline(column_trans,lr)

# %% [markdown]
# ### Fitting the model

# %%
pipe.fit(X_train,y_train)
# Out:
# c:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Ambassador Classic', 'Audi A3', 'Audi A4', 'Audi A6', 'Audi A7',
# ...

# %% [markdown]
# ### Predict the outputs

# %%
y_pred=pipe.predict(X_test)

# %%
y_pred
# Out:
# array([ 0.80687535, 35.53325627,  7.90099594, ...,  6.12162516,
#         4.80291039, 16.06472415])

# %% [markdown]
# ### Checking R2 Score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7468463142083475

# %% [markdown]
# ### Finding the model with a random state of TrainTestSplit where the model was found to give maximum r2_score
#
# - Creating a model in a loop and checking the maximum r2 score

# %%
scores=[]
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 650

# %%
scores[np.argmax(scores)]
# Out:
# 0.8033793588197694

# %%
cars.head(3)
# Out:
#             Name Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0   Maruti Wagon   Mumbai  2010              72000       CNG       Manual
# 1  Hyundai Creta     Pune  2015              41000    Diesel       Manual
# 2     Honda Jazz  Chennai  2011              46000    Petrol       Manual
#
#   Owner_Type Mileage Engine  Power  Seats  Price     Type
# 0      First    26.6    998  58.16    5.0      1   Maruti
# 1      First   19.67   1582  126.2    5.0     12  Hyundai
# 2      First    18.2   1199   88.7    5.0      4    Honda

# %%
# Assume these are the columns your model was trained on
expected_columns = ['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats', 'Type']

# Input data matching the expected column structure
input_data = np.array([
    'Maruti Wagon',  # Name
    'Mumbai',        # Location
     2010,           # Year
     72000,           # Kilometers_Driven
    'CNG',           # Fuel Type
    'Manual',        # Transmission
    'First',         # owner_type
    26.6,            # Mileage
    998,             # Engine
    58.16,           # Power
    5,               # Seats
    'Maruti'         # brand Type(make sure to handle this correctly)
]).reshape(1,12)

# Create DataFrame ensuring column names match
input_df = pd.DataFrame(columns=expected_columns, data=input_data)

# Ensure that numeric columns are of the correct type
input_df['Year'] = input_df['Year'].astype(int)
input_df['Mileage'] = input_df['Mileage'].astype(float)
input_df['Engine'] = input_df['Engine'].astype(float)
input_df['Kilometers_Driven'] = input_df['Kilometers_Driven'].astype(int)
input_df['Power'] = input_df['Power'].astype(float)
input_df['Seats'] = input_df['Seats'].astype(int)

# Now predict
predicted_price = pipe.predict(input_df)
print(predicted_price)
# Out:
# [-3.75805599]

# %% [markdown]
# ### The best model is found at a certain random state

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.8033793588197694

# %% [markdown]
# ### import pickle

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame(columns=['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats', 'Type'],data = np.array([
    'Maruti Wagon',  # Name
    'Mumbai',        # Location
     2010,           # Year
     72000,           # Kilometers_Driven
    'CNG',           # Fuel Type
    'Manual',        # Transmission
    'First',         # owner_type
    26.6,            # Mileage
    998,             # Engine
    58.16,           # Power
    5,               # Seats
    'Maruti'         # brand Type(make sure to handle this correctly)
]).reshape(1,12)))
# Out:
# array([-3.68901028])

# %%
cars.head()
# Out:
#             Name    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0   Maruti Wagon      Mumbai  2010              72000       CNG       Manual
# 1  Hyundai Creta        Pune  2015              41000    Diesel       Manual
# 2     Honda Jazz     Chennai  2011              46000    Petrol       Manual
# 3  Maruti Ertiga     Chennai  2012              87000    Diesel       Manual
# 4        Audi A4  Coimbatore  2013              40670    Diesel    Automatic
#
#   Owner_Type Mileage Engine  Power  Seats  Price     Type
# 0      First    26.6    998  58.16    5.0      1   Maruti
# 1      First   19.67   1582  126.2    5.0     12  Hyundai
# 2      First    18.2   1199   88.7    5.0      4    Honda
# 3      First   20.77   1248  88.76    7.0      6   Maruti
# 4     Second    15.2   1968  140.8    5.0     17     Audi

# %%
pipe.predict(pd.DataFrame(columns=['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats', 'Type'],data=np.array(['Hyundai Creta','Pune',2015,41000,'Diesel', 'Manual','First', 19.67, 1582, 126.2, 5,'Hyundai']).reshape(1,12)))
# Out:
# array([11.70640225])

# %%
pipe.predict(pd.DataFrame(columns=['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats', 'Type'],data=np.array(['Hyundai Creta','Pune',2019,70000,'Diesel', 'Manual','Second', 19.67, 1982, 126.2, 5,'Hyundai']).reshape(1,12)))
# Out:
# array([16.19133052])
